# %% [markdown]
# # Final Project: Data Science notebook

# %% [markdown]
# ## Introduction
# In this notebook, we summarize some of the key languages, libraries, and tools used by data scientists.
# We also demonstrate basic arithmetic operations using Python.

# %% [markdown]
# ## Data Science Languages
# The most popular languages in Data Science are:
# 1. Python
# 2. R
# 3. SQL

# %% [markdown]
# ## Data Science Libraries
# The common Python libraries in Data Science are:
# Python:
# 1. Pandas
# 2. NumPy
# 3. Matplotlib
# 4. Seaborn
# 4. Scikit-learn
# 5. TensorFlow
# 6. Keras
# 7. Pytorch

# %% [markdown]
# ## Data Science Tools
# Data Management: MySQL, PostgreSQL, MongoDB
# Data Visualization: Tableau, PowerBI, Matplotlib
# Data Analysis: Pyhton, R
# Machine Learning: Scikit-learn, TensorFlow, PyTorch

# %% [markdown]
# ## Arithmetic Expressions Examples

# %%
# Multiply and add numbers
(3 * 2 * 3) + 7
# Out:
# 25

# %%
# Convert minutes to hours
minutes = 120
hours = minutes / 60
hours
# Out:
# 2.0

# %% [markdown]
# ## Objectives
# - List popular languages for Data Science
# - List commonly used libraries
# - Create a simple table of tools
# - Perform basic arithmetic operations in Python
# - Convert time units

# %% [markdown]
# ## Author: Sara Guillén
